# %%
# !pip install xgboost
# Out:
# ...
#   Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', OSError(0, 'Error'))': /simple/xgboost/
#   Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', OSError(0, 'Error'))': /simple/xgboost/
#   Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', OSError(0, 'Error'))': /simple/xgboost/
#   Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', OSError(0, 'Error'))': /simple/xgboost/
#   Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', OSError(0, 'Error'))': /simple/xgboost/
# ...

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
sample = pd.read_csv('SampleSubmission.csv')
variable_descriptions = pd.read_csv('variable_descriptions.csv')

# %%
def showhead(data):
    print(f'Data sample is shown below {data.sample(4).T}')
    print(f'This is a sample of the data head {data.head()}')
    
data = [train, test, sample, variable_descriptions]
'''for i in data:
    showhead(i)'''
# Out:
# 'for i in data:\n    showhead(i)'

# %%
train.head()
# Out:
#                ward  total_households  total_individuals     target     dw_00  \
# 0  41601001: Ward 1        1674.45058         5888.20750  16.773757  0.933841
# 1  41601002: Ward 2        1736.99230         6735.33812  21.496661  0.696940
# 2  41601003: Ward 3        2403.57591         7273.04995  10.931425  0.810545
# 3  41601004: Ward 4        1740.78737         5734.49046  23.119257  0.659914
# 4  41601005: Ward 5        1730.51451         6657.23835  13.652252  0.950575
#
#       dw_01     dw_02     dw_03     dw_04     dw_05    ...        pw_03  \
# 0  0.000846  0.005490  0.000676  0.000000  0.001372    ...     0.002848
# 1  0.001253  0.004402  0.000000  0.002301  0.001323    ...     0.014566
# 2  0.004517  0.008891  0.003986  0.007735  0.000956    ...     0.057560
# 3  0.000000  0.006129  0.000000  0.000813  0.037245    ...     0.000000
# 4  0.000655  0.001473  0.000598  0.006999  0.000818    ...     0.004859
#
# ...

# %%
sample.head(10)
# Out:
#                ward  target
# 0  21001001: Ward 1   21.87
# 1  21001002: Ward 2   65.94
# 2  21001003: Ward 3   83.65
# 3  21001004: Ward 4     NaN
# 4  21001005: Ward 5     NaN
# 5  21001006: Ward 6     NaN
# 6  21001007: Ward 7     NaN
# 7  21002001: Ward 1     NaN
# 8  21002002: Ward 2     NaN
# 9  21002003: Ward 3     NaN

# %%
train.shape
# Out:
# (2822, 63)

# %%
train.describe()
# Out:
#        total_households  total_individuals       target        dw_00  \
# count       2822.000000        2822.000000  2822.000000  2822.000000
# mean        3665.281214       12869.130053    24.507554     0.712196
# std         3266.364522        9696.690518    10.294387     0.214035
# min            1.000000         402.000000     0.000000     0.000000
# 25%         1778.858235        7071.205695    16.751556     0.594212
# 50%         2398.249935        9366.989680    24.156670     0.766841
# 75%         3987.080563       14241.233015    32.226553     0.881708
# max        39684.942130       91716.746370    55.528423     0.994962
#
#              dw_01        dw_02        dw_03        dw_04        dw_05  \
# count  2822.000000  2822.000000  2822.000000  2822.000000  2822.000000
# mean      0.092616     0.032043     0.006057     0.008665     0.006289
# std       0.182852     0.080253     0.019374     0.030697     0.024606
# ...

# %%
train.head()
# Out:
#                ward  total_households  total_individuals     target     dw_00  \
# 0  41601001: Ward 1        1674.45058         5888.20750  16.773757  0.933841
# 1  41601002: Ward 2        1736.99230         6735.33812  21.496661  0.696940
# 2  41601003: Ward 3        2403.57591         7273.04995  10.931425  0.810545
# 3  41601004: Ward 4        1740.78737         5734.49046  23.119257  0.659914
# 4  41601005: Ward 5        1730.51451         6657.23835  13.652252  0.950575
#
#       dw_01     dw_02     dw_03     dw_04     dw_05    ...        pw_03  \
# 0  0.000846  0.005490  0.000676  0.000000  0.001372    ...     0.002848
# 1  0.001253  0.004402  0.000000  0.002301  0.001323    ...     0.014566
# 2  0.004517  0.008891  0.003986  0.007735  0.000956    ...     0.057560
# 3  0.000000  0.006129  0.000000  0.000813  0.037245    ...     0.000000
# 4  0.000655  0.001473  0.000598  0.006999  0.000818    ...     0.004859
#
# ...

# %%
train.isna().sum()
# Out:
# ward                 0
# total_households     0
# total_individuals    0
# target               0
# dw_00                0
# dw_01                0
# dw_02                0
# dw_03                0
# dw_04                0
# dw_05                0
# dw_06                0
# dw_07                0
# dw_08                0
# dw_09                0
# dw_10                0
# dw_11                0
# dw_12                0
# dw_13                0
# psa_00               0
# psa_01               0
# psa_02               0
# psa_03               0
# psa_04               0
# stv_00               0
# stv_01               0
# car_00               0
# car_01               0
# lln_00               0
# lln_01               0
# lan_00               0
#                     ..
# lan_04               0
# lan_05               0
# lan_06               0
# lan_07               0
# lan_08               0
# lan_09               0
# lan_10               0
# lan_11               0
# lan_12               0
# ...
