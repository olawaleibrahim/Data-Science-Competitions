# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.metrics as sklm
import xgboost as xgb
import matplotlib

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
submissions = pd.read_csv('submissionfile.csv')
vd = pd.read_csv('VariableDefinitions.csv')

# %%
train_new = train.drop('bank_account', axis=1)

# %%
from sklearn import preprocessing

# %%
for i in train_new.columns:
    if train_new[i].dtype == 'object':
        label = preprocessing.LabelEncoder()
        label.fit(list(train_new[i].values))
        train_new[i] = label.transform(list(train_new[i].values))
train_new.head()
# Out:
#    country  year  uniqueid  location_type  cellphone_access  household_size  \
# 0        0  2018         0              0                 1               3
# 1        0  2018      1111              0                 0               5
# 2        0  2018      2222              1                 1               5
# 3        0  2018      3333              0                 1               5
# 4        0  2018      4444              1                 0               8
#
#    age_of_respondent  gender_of_respondent  relationship_with_head  \
# 0                 24                     0                       5
# 1                 70                     0                       1
# 2                 26                     1                       3
# 3                 34                     0                       1
# 4                 26                     1                       0
#
#    marital_status  education_level  job_type
# 0               2                3         9
# ...

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# %%
train.head()
# Out:
#   country  year    uniqueid bank_account location_type cellphone_access  \
# 0   Kenya  2018  uniqueid_1          Yes         Rural              Yes
# 1   Kenya  2018  uniqueid_2           No         Rural               No
# 2   Kenya  2018  uniqueid_3          Yes         Urban              Yes
# 3   Kenya  2018  uniqueid_4           No         Rural              Yes
# 4   Kenya  2018  uniqueid_5           No         Urban               No
#
#    household_size  age_of_respondent gender_of_respondent  \
# 0               3                 24               Female
# 1               5                 70               Female
# 2               5                 26                 Male
# 3               5                 34               Female
# 4               8                 26                 Male
#
#   relationship_with_head           marital_status  \
# 0                 Spouse  Married/Living together
# 1      Head of Household                  Widowed
# ...

# %%
train = pd.get_dummies(train, columns=['country'])

# %%
train.head()
# Out:
#    year    uniqueid bank_account location_type cellphone_access  \
# 0  2018  uniqueid_1          Yes         Rural              Yes
# 1  2018  uniqueid_2           No         Rural               No
# 2  2018  uniqueid_3          Yes         Urban              Yes
# 3  2018  uniqueid_4           No         Rural              Yes
# 4  2018  uniqueid_5           No         Urban               No
#
#    household_size  age_of_respondent gender_of_respondent  \
# 0               3                 24               Female
# 1               5                 70               Female
# 2               5                 26                 Male
# 3               5                 34               Female
# 4               8                 26                 Male
#
#   relationship_with_head           marital_status  \
# 0                 Spouse  Married/Living together
# 1      Head of Household                  Widowed
# 2         Other relative     Single/Never Married
# ...

# %%
train.head()
# Out:
#   country  year    uniqueid bank_account location_type cellphone_access  \
# 0   Kenya  2018  uniqueid_1          Yes         Rural              Yes
# 1   Kenya  2018  uniqueid_2           No         Rural               No
# 2   Kenya  2018  uniqueid_3          Yes         Urban              Yes
# 3   Kenya  2018  uniqueid_4           No         Rural              Yes
# 4   Kenya  2018  uniqueid_5           No         Urban               No
#
#    household_size  age_of_respondent gender_of_respondent  \
# 0               3                 24               Female
# 1               5                 70               Female
# 2               5                 26                 Male
# 3               5                 34               Female
# 4               8                 26                 Male
#
#   relationship_with_head           marital_status  \
# 0                 Spouse  Married/Living together
# 1      Head of Household                  Widowed
# ...

# %%
train = train.drop('uniqueid', axis=1)

# %%
for i in train.columns:
    if train[i].dtype =='object':
        train = pd.get_dummies(train, columns=[i])

# %%
train.head()
# Out:
#    year  household_size  age_of_respondent  country_Kenya  country_Rwanda  \
# 0  2018               3                 24              1               0
# 1  2018               5                 70              1               0
# 2  2018               5                 26              1               0
# 3  2018               5                 34              1               0
# 4  2018               8                 26              1               0
#
#    country_Tanzania  country_Uganda  bank_account_No  bank_account_Yes  \
# 0                 0               0                0                 1
# 1                 0               0                1                 0
# 2                 0               0                0                 1
# 3                 0               0                1                 0
# 4                 0               0                1                 0
#
#    location_type_Rural           ...            \
# 0                    1           ...
# ...

# %%
scaler4 = preprocessing.StandardScaler().fit(train.values[:, :3])
train.values[:, :3] = scaler4.transform(train.values[:,:3])
train[:, :3]
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\hp\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-1c10e173bca7> in <module>()
#       1 scaler4 = preprocessing.StandardScaler().fit(train.values[:, :3])
#       2 train.values[:, :3] = scaler4.transform(train.values[:,:3])
# ----> 3 train[:, :3]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# ...

# %%
train.values[:, :3]
# Out:
# array([[2018,    3,   24],
#        [2018,    5,   70],
#        [2018,    5,   26],
#        ...,
#        [2018,    5,   27],
#        [2018,    7,   30],
#        [2018,   10,   20]], dtype=int64)

# %%
train.head()
# Out:
#    year  household_size  age_of_respondent  country_Kenya  country_Rwanda  \
# 0  2018               3                 24              1               0
# 1  2018               5                 70              1               0
# 2  2018               5                 26              1               0
# 3  2018               5                 34              1               0
# 4  2018               8                 26              1               0
#
#    country_Tanzania  country_Uganda  bank_account_No  bank_account_Yes  \
# 0                 0               0                0                 1
# 1                 0               0                1                 0
# 2                 0               0                0                 1
# 3                 0               0                1                 0
# 4                 0               0                1                 0
#
#    location_type_Rural           ...            \
# 0                    1           ...
# ...
